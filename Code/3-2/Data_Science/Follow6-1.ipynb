# %%
tbl <- table(mtcars$cyl)
tbl
# Out:
#  4  6  8
# 11  7 14

# %%
barplot(tbl)
# Out:
# plot without title

# %%
tbl <- table(mtcars$cyl)
barplot(tbl, horiz = T)
# Out:
# plot without title

# %%
tbl <- table(mtcars$cyl)
barplot(tbl, col='gold', border='red')
# Out:
# plot without title

# %%
tbl >- table(mtcars$cyl)
barplot(tbl, col=c('red', 'blue', 'green'))
# Out:
#    4    6    8
# TRUE TRUE TRUE
# plot without title

# %%
crosstbl <- table(mtcars$gear, mtcars$cyl)
crosstbl
# Out:
#
#      4  6  8
#   3  1  2 12
#   4  8  4  0
#   5  2  1  2

# %%
barplot(crosstbl, col=c('blue', 'red', 'orange'),
    legend=rownames(crosstbl))
# Out:
# plot without title

# %%
barplot(crosstbl, col=c('blue', 'red', 'orange'),
        legend=rownames(crosstbl), beside=T)
# Out:
# plot without title

# %%
data <- c(36,38,55)
names(data) <- c("배드민턴", "탁구", "볼링")
print(data)
# Out:
# 배드민턴     탁구     볼링
#       36       38       55

# %%
barplot(data, col='yellow')
# Out:
# plot without title

# %%
data <- c(21, 16, 23, 15, 22, 32)
member <- matrix(data, 3, 2)
print(member)
# Out:
#      [,1] [,2]
# [1,]   21   15
# [2,]   16   22
# [3,]   23   32

# %%
colnames(member) <- c("남", "여")
rownames(member) <- c("배드민턴", "탁구", "볼링")
print(member)
# Out:
#          남 여
# 배드민턴 21 15
# 탁구     16 22
# 볼링     23 32

# %%
barplot(member, col=c("gold","green", "pink"),
    legend=rownames(member))
# Out:
# plot without title

# %%
# 행과 열 바꿔보자
m2 <- t(member)
barplot(m2, col=c("gold", "green"),
        legend=rownames(m2))
# Out:
# plot without title

# %%
# 그룹별 평균
tbl <- tapply(mtcars$mpg, mtcars$cyl, mean)
barplot(tbl, col="gold", border="red")
# Out:
# plot without title

# %%
print(tbl)
# Out:
#        4        6        8
# 26.66364 19.74286 15.10000

# %%
# 파이그래프
data <- c(36, 38, 55)
names(data) <- c("배드민턴", "탁구", "볼링")
pie(data, col=runif(3,0,255))
# Out:
# plot without title

# %%
# + 비율 표시

pct <- round(data/sum(data)*100, 2)
label <- paste0(names(data), "(", pct, "%)")
pie(data, labels=label, col=runif(3, 0, 255))
# Out:
# plot without title

# %%
# 2023년 교통사고 데이터 읽기 - csv

data <- read.csv("../mydata/2023년_도로교통공단_일자별 시군구별 교통사고 건수.csv", fileEncoding="CP949")
head(data, 2)
# Out:
#   발생월 발생일 시도 시군구 사고건수 사망자수 중상자수 경상자수 부상신고자수
# 1 1      1      서울 용산구 4        0        0         5       0
# 2 1      1      서울 성동구 4        0        0        13       0

# %%
options(repr.plot.width=10)

tbl <- tapply(data$`사고건수`, data$`시도`, sum)
barplot(tbl, col='gold', border='red')
# Out:
# plot without title

# %%
options(repr.plot.width=8)

tbl <- tapply(data$`사고건수`, data$`발생월`, mean)
names(tbl) <- paste0(1:12, "월")
barplot(tbl, col='gold', border='red')
# Out:
# plot without title

# %%
help(rivers)
# Out:
# rivers                package:datasets                 R Documentation
#
# s
#
# n:
#
#      This data set gives the lengths (in miles) of 141 “major” rivers
#      in North America, as compiled by the US Geological Survey.
#
# e:
#
#      rivers
#
# t:
#
#      A vector containing 141 observations.
#
# e:
#
#      World Almanac and Book of Facts, 1975, page 406.
#
# s:
#
#      McNeil, D. R. (1977) _Interactive Data Analysis_.  New York:
#      Wiley.

# %%
hist(rivers)
# Out:
# Plot with title “Histogram of rivers”

# %%
bins <- c(0:4)*1000
hist(rivers, breaks=bins, col='gold', border='red')
# Out:
# Plot with title “Histogram of rivers”

# %%
options(repr.plot.width=12)
par(mfrow=c(1,2))

bins <- c(0:4)*1000
hist(rivers, breaks = bins, col='gold', border='red')
hist(rivers, breaks = bins, col='gold', border = 'red', right=T)
# Out:
# Plot with title “Histogram of rivers”

# %%
options(repr.plot.width=7)
boxplot(mtcars$mpg, col='green')
# Out:
# plot without title

# %%
summary(mtcars$mpg)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   10.40   15.43   19.20   20.09   22.80   33.90

# %%
boxplot(mpg ~  cyl, data=mtcars, col=c('gold', 'green', 'pink'))
# Out:
# plot without title

# %%
# 연속형 자료의 산점도
plot(cars$speed, cars$dist, col='blue')
# Out:
# plot without title

# %%
data <- read.csv("../mydata/도로교통공단_시군구별 월별 교통사고 통계_20231231.csv", 
                 fileEncoding="CP949")
jongro <- subset(data, 시군구=="종로구")
jongro
# Out:
#    시도 시군구 발생월 사고건수 사망자수 중상자수 경상자수 부상신고자수
# 1  서울 종로구  1      77      2        15        79      14
# 2  서울 종로구  2      66      0        17        59       8
# 3  서울 종로구  3      67      0        15        80       2
# 4  서울 종로구  4      73      1        17        67       6
# 5  서울 종로구  5      88      0        21       103      12
# 6  서울 종로구  6      82      0        17        78       6
# 7  서울 종로구  7      95      0        16        97       8
# 8  서울 종로구  8      83      1        21        87       6
# 9  서울 종로구  9      81      1        28        95       9
# 10 서울 종로구 10      96      2        23        93       4
# 11 서울 종로구 11      80      1        21        76       2
# 12 서울 종로구 12     100      0        29        95       5

# %%
plot(jongro$`발생월`, jongro$`사고건수`, type="o", col='blue')
# Out:
# plot without title

# %%
plot(cars$speed, cars$dist)
# Out:
# plot without title

# %%
plot(cars$speed, cars$dist, main="속력에 따른 제동거리",
    xlab="속력", ylab="제동거리")
# Out:
# Plot with title “속력에 따른 제동거리”

# %%
plot(cars$speed, cars$dist, main="속력에 따른 제동거리",
    xlab="속력", ylab="제동거리",
    xlim=c(0,50), ylim=c(0,200))
# Out:
# Plot with title “속력에 따른 제동거리”

# %%
plot(cars$speed, cars$dist, main="속력에 따른 제동거리",
    xlab="속력", ylab="제동거리",
    xlim=c(0,50), ylim=c(0,200))

    # 축의 눈금 지정
axis(side=1, at=seq(0,50,5), labels=seq(0,50,5))  # x 축
axis(side=2, at=seq(0,200,25), labels=seq(0,200,25))  # y 축
# Out:
# Plot with title “속력에 따른 제동거리”

# %%
plot(cars$speed, cars$dist, main="속력에 따른 제동거리",
    xlab="속력", ylab="제동거리", axes=F)
# Out:
# Plot with title “속력에 따른 제동거리”

# %%
data <- read.csv("../mydata/도로교통공단_시군구별 월별 교통사고 통계_20231231.csv",
                 fileEncoding="CP949")

chungju <- subset(data, 시군구=="충주시")
chungju
# Out:
#      시도 시군구 발생월 사고건수 사망자수 중상자수 경상자수 부상신고자수
# 1093 충북 충주시  1      78      1        31        72      1
# 1094 충북 충주시  2      60      2         9        72      0
# 1095 충북 충주시  3      79      0        19        96      1
# 1096 충북 충주시  4      89      2        34        95      1
# 1097 충북 충주시  5     105      0        35       123      1
# 1098 충북 충주시  6      89      2        19       120      1
# 1099 충북 충주시  7      90      4        31        92      6
# 1100 충북 충주시  8      74      2        32        79      0
# 1101 충북 충주시  9      95      0        27       126      3
# 1102 충북 충주시 10      91      1        26       128      0
# 1103 충북 충주시 11      90      2        25       123      0
# 1104 충북 충주시 12      86      0        19       114      0

# %%
plot(chungju$`발생월`, chungju$`사고건수`)
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="l", col='blue')
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='blue')
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='blue', lty=1)
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='blue', lty=3)
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='blue', lty=2, pch=21, cex=2)
# Out:
# plot without title

# %%
plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='blue', lty=2, pch=21, cex=2, bg='red')
# Out:
# plot without title

# %%
# 옵션 - 그래프 크기기
options(repr.plot.width=4, repr.plot.height=8)

plot(cars$speed, cars$dist, main="산점도")
# Out:
# Plot with title “산점도”

# %%
options(repr.plot.width=4, repr.plot.height=7)

plot(cars$speed, cars$dist, main="산점도",
    cex.main=3 , cex.lab=2, cex.axis=1)
# Out:
# Plot with title “산점도”

# %%
options(repr.plot.width=7, repr.plot.height=7)

plot(cars$speed, cars$dist, main="산점도",
    cex.main=3, cex.lab=2, cex.axis=1)
# Out:
# Plot with title “산점도”

# %%
par(mar=c(5,5,5,5))
plot(cars$speed, cars$dist, main="산점도",
    cex.main=1, cex.lab=3, cex.axis=2)
# Out:
# Plot with title “산점도”

# %%
library(dplyr)

data <- read.csv("../mydata/도로교통공단_시군구별 월별 교통사고 통계_20231231.csv",
                 fileEncoding="CP949")

chungju <- filter(data, 시군구=="충주시")
cheongju <- filter(data, 시군구=="청주시")
jecheon <- filter(data, 시군구=="제천시")

chungju
# Out:
#    시도 시군구 발생월 사고건수 사망자수 중상자수 경상자수 부상신고자수
# 1  충북 충주시  1      78      1        31        72      1
# 2  충북 충주시  2      60      2         9        72      0
# 3  충북 충주시  3      79      0        19        96      1
# 4  충북 충주시  4      89      2        34        95      1
# 5  충북 충주시  5     105      0        35       123      1
# 6  충북 충주시  6      89      2        19       120      1
# 7  충북 충주시  7      90      4        31        92      6
# 8  충북 충주시  8      74      2        32        79      0
# 9  충북 충주시  9      95      0        27       126      3
# 10 충북 충주시 10      91      1        26       128      0
# 11 충북 충주시 11      90      2        25       123      0
# 12 충북 충주시 12      86      0        19       114      0

# %%
options(repr.plot.width=10)
par(mfrow = c(1,2))

plot(chungju$`발생월`, chungju$`사고건수`, type="o", col='red', main="충주시")
plot(cheongju$`발생월`, cheongju$`사고건수`, type="o", col='red', main="청주시")
# Out:
# Plot with title “청주시”

# %%
# y축의 범위 일치
options(repr.plot.width=10)
par(mfrow = c(1,2))

plot(chungju$`발생월`, chungju$`사고건수`, type='o', pch=20,col='red', 
     main="충주시", ylim=c(0,450))
axis(side=1, at=1:12, labels=1:12)

plot(cheongju$`발생월`, cheongju$`사고건수`, type='o', pch=20, col='blue', 
     main="청주시", ylim=c(0,450))
axis(side=1, at=1:12, labels=1:12)
# Out:
# Plot with title “청주시”

# %%
par(mfrow = c(2,1))

plot(chungju$`발생월`, chungju$`사고건수`, type='o', pch=20,col='red', 
     main="충주시", ylim=c(0,450))
axis(side=1, at=1:12, labels=1:12)

plot(cheongju$`발생월`, cheongju$`사고건수`, type='o', pch=20, col='blue', 
     main="청주시", ylim=c(0,450))
axis(side=1, at=1:12, labels=1:12)
# Out:
# Plot with title “청주시”

# %%
library(dplyr)

data <- read.csv("../mydata/도로교통공단_시군구별 월별 교통사고 통계_20231231.csv",
        fileEncoding="CP949")

chungju <- filter(data, 시군구=="충주시")
cheongju <- filter(data, 시군구=="청주시")
jecheon <- filter(data, 시군구=="제천시")

jecheon
# Out:
#    시도 시군구 발생월 사고건수 사망자수 중상자수 경상자수 부상신고자수
# 1  충북 제천시  1     37       1         8       36        2
# 2  충북 제천시  2     34       0        13       36        3
# 3  충북 제천시  3     45       1         9       45        9
# 4  충북 제천시  4     69       0        20       84        5
# 5  충북 제천시  5     81       3        17       81       10
# 6  충북 제천시  6     63       2        16       82        8
# 7  충북 제천시  7     58       1        20       70        6
# 8  충북 제천시  8     68       1        15       79       10
# 9  충북 제천시  9     68       1        32       75        5
# 10 충북 제천시 10     76       1        19       81       11
# 11 충북 제천시 11     65       0        20       80        6
# 12 충북 제천시 12     73       0        11       94        6

# %%
# 기본 그래프 그리기
options(repr.plot.width=8)

plot(chungju$`발생월`, chungju$`사고건수`,
     type='o', pch=20, col='red', ylim=c(0,450),
     main="충북 3개 도시 월 교통사고 건수", 
     xlab="월", ylab="교통사고 건수")
# Out:
# Plot with title “충북 3개 도시 월 교통사고 건수”

# %%
plot(chungju$`발생월`, chungju$`사고건수`,
     type='o', pch=20, col='red', ylim=c(0,450),
     main="충북 3개 도시 월 교통사고 건수", 
     xlab="월", ylab="교통사고 건수")
axis(side=1, at=1:12, labels=1:12)
axis(side=2, at=seq(0,450,50), labels=seq(0,450,50))
grid(col='green')
# Out:
# Plot with title “충북 3개 도시 월 교통사고 건수”

# %%
# 두 지역의 그래프 가가
plot(chungju$`발생월`, chungju$`사고건수`,
     type='o', pch=20, col='red', ylim=c(0,450),
     main="충북 3개 도시 월 교통사고 건수", 
     xlab="월", ylab="교통사고 건수")
axis(side=1, at=1:12, labels=1:12)
axis(side=2, at=seq(0,450,50), labels=seq(0,450,50))
grid(col='green')

points(cheongju$`발생월`, cheongju$`사고건수`, col='blue', pch=19)
lines(cheongju$`발생월`, cheongju$`사고건수`, col='blue', lty=2)

points(jecheon$`발생월`, jecheon$`사고건수`, col='darkgreen', pch=17)
lines(jecheon$`발생월`, jecheon$`사고건수`, col='darkgreen', lty=3)
# Out:
# Plot with title “충북 3개 도시 월 교통사고 건수”

# %%
# 범례추가_최종본
plot(chungju$`발생월`, chungju$`사고건수`,
     type='o', pch=20, col='red', ylim=c(0,450),
     main="충북 3개 도시 월 교통사고 건수", 
     xlab="월", ylab="교통사고 건수")
axis(side=1, at=1:12, labels=1:12)
axis(side=2, at=seq(0,450,50), labels=seq(0,450,50))
grid(col='green')

points(cheongju$`발생월`, cheongju$`사고건수`, col='blue', pch=19)
lines(cheongju$`발생월`, cheongju$`사고건수`, col='blue', lty=2)

points(jecheon$`발생월`, jecheon$`사고건수`, col='darkgreen', pch=17)
lines(jecheon$`발생월`, jecheon$`사고건수`, col='darkgreen', lty=3)

legend('topleft', legend=c("충주시", "청주시", "제천시"),
       col=c("blue", "red", "darkgreen"), lty=c(1,2,3), pch=c(20,19,17))
# Out:
# Plot with title “충북 3개 도시 월 교통사고 건수”
